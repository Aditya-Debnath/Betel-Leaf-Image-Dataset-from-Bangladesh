# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(55).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(152).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(69).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(116).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(191).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(179).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(192).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(38).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(230).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(151).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(174).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(194).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(74).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(126).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(244).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(64).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(32).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(231).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(245).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(243).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(17).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(7).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(94).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(235).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(48).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(159).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(9).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(113).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(77).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(93).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(28).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(163).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(68).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(40).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(115).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(146).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(143).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(130).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(209).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(100).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(83).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(53).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(86).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(155).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(190).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(95).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(214).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(217).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(131).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(135).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(234).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(19).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(44).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(182).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(81).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(91).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(4).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(103).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(27).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(52).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(124).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(219).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(21).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(153).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(183).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(67).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(41).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(229).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(165).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(188).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(246).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(59).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(237).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(107).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(123).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(75).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(170).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(236).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(178).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(29).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(198).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(97).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(185).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(37).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(89).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(121).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(240).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(62).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(226).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(224).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(128).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(216).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(145).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(43).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(250).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(187).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(137).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(193).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(168).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(239).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(13).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(58).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(184).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(71).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(3).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(202).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(208).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(1).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(51).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(175).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(56).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(98).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(25).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(207).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(33).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(154).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(205).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(136).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(78).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(127).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(99).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(80).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(210).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(149).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(167).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(10).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(144).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(12).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(54).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(206).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(247).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(221).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(47).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(181).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(65).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(23).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(102).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(122).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(199).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(61).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(14).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(220).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(176).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(36).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(157).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(148).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(45).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(160).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(195).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(213).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(186).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(76).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(31).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(85).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(156).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(20).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(196).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(139).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(180).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(39).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(92).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(109).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(112).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(84).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(30).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(201).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(120).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(138).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(212).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(90).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(189).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(46).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(129).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(72).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(147).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(79).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(88).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(242).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(57).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(8).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(2).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(66).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(50).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(5).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(177).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(60).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(63).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(223).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(169).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(238).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(16).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(211).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(82).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(222).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(204).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(171).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(15).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(173).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(87).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(22).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(111).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(150).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(70).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(227).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(49).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(105).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(249).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(114).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(110).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(24).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(34).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(133).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(125).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(117).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(118).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(215).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(225).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(35).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(106).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(158).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(162).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(73).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(18).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(140).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(142).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(11).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(232).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(172).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(134).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(248).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(200).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(6).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(228).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(26).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(233).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(241).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(42).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(141).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(161).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(119).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(203).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(108).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(101).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(132).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(218).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(104).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(164).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(166).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(197).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Healthy Leaf/Healthy_Leaf(96).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(231).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(243).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(54).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(242).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(209).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(35).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(177).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(155).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(66).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(164).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(150).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(160).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(119).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(206).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(225).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(192).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(244).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(165).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(26).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(39).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(37).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(94).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(127).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(219).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(49).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(113).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(148).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(247).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(175).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(123).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(75).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(223).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(17).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(130).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(230).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(227).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(62).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(161).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(197).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(248).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(220).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(81).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(204).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(126).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(36).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(141).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(139).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(65).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(33).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(16).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(69).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(238).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(124).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(235).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(117).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(18).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(109).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(4).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(46).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(174).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(71).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(99).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(72).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(89).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(146).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(12).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(144).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(6).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(45).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(28).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(191).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(122).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(236).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(51).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(208).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(172).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(70).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(63).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(156).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(102).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(78).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(110).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(112).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(245).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(210).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(114).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(91).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(173).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(246).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(233).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(136).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(222).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(188).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(73).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(180).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(159).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(181).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(185).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(133).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(44).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(21).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(166).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(137).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(19).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(88).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(3).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(76).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(217).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(86).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(186).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(68).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(198).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(42).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(118).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(121).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(50).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(108).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(169).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(30).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(195).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(229).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(162).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(34).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(138).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(171).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(190).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(152).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(211).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(83).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(128).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(205).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(184).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(97).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(77).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(134).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(143).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(214).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(90).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(115).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(116).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(234).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(183).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(189).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(15).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(53).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(250).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(158).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(57).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Dried Leaf/Dried_Leaf(96).jpg
# ...
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(129).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(50).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(74).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(54).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(95).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(221).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(180).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(229).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(151).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(237).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(203).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(63).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(127).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(7).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(194).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(70).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(103).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(51).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(64).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(23).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(249).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(193).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(243).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(222).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(207).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(73).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(9).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(53).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(158).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(35).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(202).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(101).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(58).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(174).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(171).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(159).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(89).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(121).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(242).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(182).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(33).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(160).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(43).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(59).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(162).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(86).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(67).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(118).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(61).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(68).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(22).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(154).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(220).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(147).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(48).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(45).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(130).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(81).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(108).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(168).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(216).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(3).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(192).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(38).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(85).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(248).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(250).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(87).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(211).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(28).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(150).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(239).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(139).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(114).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(173).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(4).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(75).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(79).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(186).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(135).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(244).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(102).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(201).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(218).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(219).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(109).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(24).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(15).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(189).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(208).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(27).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(137).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(20).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(65).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(37).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(14).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(167).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(1).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(115).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(141).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(36).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(234).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(142).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(10).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(76).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(90).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(44).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(131).jpg
# /kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(29).jpg

# %%
# ==============================================================================
# 1. IMPORT LIBRARIES
# ==============================================================================
# Install torchinfo if it's not already available
# !pip install torchinfo --quiet

import time
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np
import cv2
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import torchvision
from torchvision import transforms
from torchinfo import summary
import torchvision.models as models
import torch.optim as optim
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import random
from PIL import Image
from itertools import cycle

# ==============================================================================
# 2. CONFIGURATION
# ==============================================================================
print("--- System Information ---")
try:
    gpu_info = !nvidia-smi --query-gpu=gpu_name --format=csv
    gpu_name = gpu_info[1]
    print(f"GPU: {gpu_name}")
    device = torch.device('cuda')
except Exception as e:
    gpu_name = "No GPU available"
    print(f"GPU: {gpu_name}")
    device = torch.device('cpu')

# --- Variables ---
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

## IMPORTANT: Update this path to your dataset location in Kaggle ##
data_dir = "/kaggle/input/project-dataset/Betel Leaf Image Dataset from Bangladesh/Original Images"

output_dir = "/kaggle/working/processed-dataset"
checkpoints_path = "/kaggle/working/"
os.makedirs(output_dir, exist_ok=True)

# --- Hyperparameters ---
train_batch = 32
test_batch = 16
total_class = 4
learning_rate = 0.0001
decay = 1e-4
initial_epochs = 20 # Epochs for initial training with frozen layers
finetune_epochs = 15 # Epochs for fine-tuning
patience = 5
image_size = (224, 224)

# ==============================================================================
# 3. EXPLORE AND SPLIT THE DATASET
# ==============================================================================
def load_split(split_dir):
    file_paths, labels = [], []
    for class_name in os.listdir(split_dir):
        class_dir = os.path.join(split_dir, class_name)
        if os.path.isdir(class_dir):
            for image_name in os.listdir(class_dir):
                file_paths.append(os.path.join(class_dir, image_name))
                labels.append(class_name)
    return pd.DataFrame({"file_path": file_paths, "label": labels})

data = load_split(data_dir)
train_dataframe, temp_dataframe = train_test_split(data, test_size=0.30, stratify=data['label'], random_state=seed)
validation_dataframe, test_dataframe = train_test_split(temp_dataframe, test_size=0.50, stratify=temp_dataframe['label'], random_state=seed)

# --- Visualize Dataset Split Ratios ---
sizes = {
    "Train": len(train_dataframe),
    "Validation": len(validation_dataframe),
    "Test": len(test_dataframe),
}

total = sum(sizes.values())
ratios = {k: (v / total) * 100 for k, v in sizes.items()}

print("\n--- Dataset Split Ratios ---")
for split in sizes.keys():
    print(f"{split}: {sizes[split]} images ({ratios[split]:.2f}%)")

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].pie(
    sizes.values(),
    labels=sizes.keys(),
    autopct="%.1f%%",
    startangle=90,
    colors=["#a6cee3", "#1f78b4", "#b2df8a"]
)
axes[0].set_title("Dataset Split Pie Chart")

axes[1].bar(sizes.keys(), sizes.values(), color=["#a6cee3", "#1f78b4", "#b2df8a"])
axes[1].set_ylabel("Number of Images")
axes[1].set_title("Dataset Split Bar Chart")
y_max = max(sizes.values()) * 1.1
axes[1].set_ylim(0, y_max)
for i, v in enumerate(sizes.values()):
    axes[1].text(i, v + total*0.01, str(v), ha='center')  
plt.tight_layout()
plt.show()

# --- Visualize Class Distribution ---
def class_distribution_plot(train_df, test_df, val_df):
    datasets = { "Train": train_df, "Validation": val_df, "Test": test_df }
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle('Class Distribution Across Datasets', fontsize=16)
    
    for ax, (split_name, df) in zip(axes, datasets.items()):
        class_counts = df['label'].value_counts().sort_index()
        class_counts.plot(kind='bar', ax=ax, color=sns.color_palette("viridis", len(class_counts)))
        ax.set_xlabel('Classes')
        ax.set_ylabel('Number of Images')
        ax.set_title(f'{split_name} Set')
        ax.set_xticklabels(class_counts.index, rotation=45, ha='right')
        
        for i, count in enumerate(class_counts):
            ax.text(i, count + 2, str(count), ha='center')
        ax.set_ylim(0, max(class_counts) * 1.2)
    
    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

class_distribution_plot(train_dataframe, test_dataframe, validation_dataframe)

# ==============================================================================
# 4. DATA PREPROCESSING (Resize and Save)
# ==============================================================================
def data_preprocess(df, split_name, size, quality=95):
    split_dir = os.path.join(output_dir, split_name)
    os.makedirs(split_dir, exist_ok=True)
    processed_file_paths = []
    for idx, row in tqdm(df.iterrows(), total=len(df), desc=f"Processing {split_name} set"):
        label = row['label']
        label_dir = os.path.join(split_dir, label)
        os.makedirs(label_dir, exist_ok=True)
        img = Image.open(row['file_path']).convert("RGB").resize(size, Image.Resampling.LANCZOS)
        file_name = os.path.basename(row['file_path'])
        save_path = os.path.join(label_dir, file_name)
        img.save(save_path, optimize=True, quality=quality)
        processed_file_paths.append(save_path)
    df['file_path'] = processed_file_paths
    return df

train_dataframe = data_preprocess(train_dataframe, "train", size=image_size)
validation_dataframe = data_preprocess(validation_dataframe, "validation", size=image_size)
test_dataframe = data_preprocess(test_dataframe, "test", size=image_size)

# ==============================================================================
# 5. DATASET CLASS, TRANSFORMS, AND DATALOADERS
# ==============================================================================
class ImageDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform
        unique_labels = sorted(self.dataframe['label'].unique())
        self.label_map = {label: idx for idx, label in enumerate(unique_labels)}
    def __len__(self): return len(self.dataframe)
    def __getitem__(self, index):
        img_path = self.dataframe.iloc[index]['file_path']
        image = Image.open(img_path).convert("RGB")
        label = self.label_map[self.dataframe.iloc[index]['label']]
        if self.transform: image = self.transform(image)
        return image, label

def get_dataloaders(size):
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    train_transform = transforms.Compose([
        transforms.RandomRotation(degrees=15), transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5), transforms.RandomResizedCrop(size, scale=(0.9, 1.0)),
        transforms.ColorJitter(brightness=0.2, contrast=0.2), transforms.ToTensor(), normalize])
    val_test_transform = transforms.Compose([transforms.Resize(size), transforms.ToTensor(), normalize])
    train_dataset = ImageDataset(train_dataframe, transform=train_transform)
    valid_dataset = ImageDataset(validation_dataframe, transform=val_test_transform)
    test_dataset = ImageDataset(test_dataframe, transform=val_test_transform)
    print("\n--- Label Encoding ---")
    for label, idx in train_dataset.label_map.items(): print(f"{label} -> {idx}")
    train_dataloader = DataLoader(train_dataset, batch_size=train_batch, shuffle=True, num_workers=2)
    validation_dataloader = DataLoader(valid_dataset, batch_size=test_batch, shuffle=False, num_workers=2)
    test_dataloader = DataLoader(test_dataset, batch_size=test_batch, shuffle=False, num_workers=2)
    return train_dataloader, validation_dataloader, test_dataloader, train_dataset.label_map

train_dataloader, validation_dataloader, test_dataloader, label_map = get_dataloaders(size=image_size)
class_names = list(label_map.keys())

# ==============================================================================
# 6. DEEP LEARNING MODEL (MobileNetV2)
# ==============================================================================
print("\n--- Initializing MobileNetV2 Model ---")
model = models.mobilenet_v2(weights='IMAGENET1K_V1')
num_ftrs = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_ftrs, total_class)
model = model.to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=decay)
criterion = nn.CrossEntropyLoss()
summary(model, input_size=(train_batch, 3, 224, 224))

# ==============================================================================
# 7. MODEL TRAINING AND FINE-TUNING
# ==============================================================================
def train_finetune_model(model, criterion, optimizer, train_loader, val_loader, initial_epochs, finetune_epochs, patience, ckpt_path):
    train_loss_history, val_loss_history = [], []
    train_acc_history, val_acc_history = [], []
    best_val_acc = 0.0
    no_improvement_count = 0
    total_start_time = time.time()
    
    # --- STAGE 1: Initial Training (Feature Extraction) ---
    print("\n--- Stage 1: Training the Classifier (Frozen Base) ---")
    for param in model.features.parameters(): param.requires_grad = False
    for param in model.classifier.parameters(): param.requires_grad = True
    for epoch in range(initial_epochs):
        model.train(); running_loss, correct_train, total_train = 0.0, 0, 0
        progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{initial_epochs} [T]")
        for inputs, labels in progress_bar:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad(); outputs = model(inputs); loss = criterion(outputs, labels); loss.backward(); optimizer.step()
            running_loss += loss.item() * inputs.size(0); _, predicted = torch.max(outputs, 1); total_train += labels.size(0); correct_train += (predicted == labels).sum().item()
            progress_bar.set_postfix(loss=running_loss/total_train, acc=correct_train/total_train)
        epoch_train_loss = running_loss / total_train; epoch_train_acc = correct_train / total_train
        train_loss_history.append(epoch_train_loss); train_acc_history.append(epoch_train_acc)
        
        model.eval(); running_val_loss, correct_val, total_val = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs); loss = criterion(outputs, labels); running_val_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1); total_val += labels.size(0); correct_val += (predicted == labels).sum().item()
        
        epoch_val_loss = running_val_loss / total_val; epoch_val_acc = correct_val / total_val
        val_loss_history.append(epoch_val_loss); val_acc_history.append(epoch_val_acc)
        print(f"Epoch {epoch+1}/{initial_epochs} -> Train Loss: {epoch_train_loss:.3f}, Train Acc: {epoch_train_acc:.3f} | Val Loss: {epoch_val_loss:.3f}, Val Acc: {epoch_val_acc:.3f}")
        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            torch.save(model.state_dict(), os.path.join(ckpt_path, "best_model.pt"))
            print(f"✅ Best model from Stage 1 saved with validation accuracy: {best_val_acc:.3f}")
            no_improvement_count = 0
        else: no_improvement_count += 1
        if no_improvement_count >= patience: print(f"🛑 Early stopping Stage 1 after {patience} epochs with no improvement."); break
            
    # --- STAGE 2: Fine-Tuning ---
    print("\n--- Stage 2: Fine-Tuning (Unfrozen Base) ---")
    for param in model.parameters(): param.requires_grad = True
    optimizer_ft = optim.Adam(model.parameters(), lr=learning_rate / 10)
    no_improvement_count = 0
    for epoch in range(finetune_epochs):
        model.train(); running_loss, correct_train, total_train = 0.0, 0, 0
        progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{finetune_epochs} [FT]")
        for inputs, labels in progress_bar:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer_ft.zero_grad(); outputs = model(inputs); loss = criterion(outputs, labels); loss.backward(); optimizer_ft.step()
            running_loss += loss.item() * inputs.size(0); _, predicted = torch.max(outputs, 1); total_train += labels.size(0); correct_train += (predicted == labels).sum().item()
            progress_bar.set_postfix(loss=running_loss/total_train, acc=correct_train/total_train)

        epoch_train_loss = running_loss / total_train; epoch_train_acc = correct_train / total_train
        train_loss_history.append(epoch_train_loss); train_acc_history.append(epoch_train_acc)
        
        model.eval(); running_val_loss, correct_val, total_val = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs); loss = criterion(outputs, labels); running_val_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1); total_val += labels.size(0); correct_val += (predicted == labels).sum().item()

        epoch_val_loss = running_val_loss / total_val; epoch_val_acc = correct_val / total_val
        val_loss_history.append(epoch_val_loss); val_acc_history.append(epoch_val_acc)
        print(f"Epoch {epoch+1}/{finetune_epochs} -> Train Loss: {epoch_train_loss:.3f}, Train Acc: {epoch_train_acc:.3f} | Val Loss: {epoch_val_loss:.3f}, Val Acc: {epoch_val_acc:.3f}")
        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            torch.save(model.state_dict(), os.path.join(ckpt_path, "best_model.pt"))
            print(f"✅ Best model from Stage 2 saved with validation accuracy: {best_val_acc:.3f}")
            no_improvement_count = 0
        else:
            no_improvement_count += 1
            print(f"   (No improvement for {no_improvement_count} epochs)")
        if no_improvement_count >= patience: print(f"🛑 Early stopping Stage 2 after {patience} epochs with no improvement."); break
            
    total_end_time = time.time()
    print(f"\n--- Training & Fine-Tuning Finished ---")
    print(f"Total Time: {(total_end_time - total_start_time)/60:.2f} minutes")
    return train_loss_history, train_acc_history, val_loss_history, val_acc_history

# Train and fine-tune the model
train_loss, train_acc, val_loss, val_acc = train_finetune_model(
    model, criterion, optimizer, train_dataloader, validation_dataloader, 
    initial_epochs, finetune_epochs, patience, checkpoints_path
)

# --- Plot Training History ---
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss'); plt.plot(val_loss, label='Validation Loss')
plt.axvline(x=len(train_loss) - finetune_epochs - 1, color='r', linestyle='--', label='Start Fine-Tuning')
plt.xlabel('Epochs'); plt.ylabel('Loss'); plt.title('Loss over Epochs'); plt.legend()
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Train Accuracy'); plt.plot(val_acc, label='Validation Accuracy')
plt.axvline(x=len(train_acc) - finetune_epochs - 1, color='r', linestyle='--', label='Start Fine-Tuning')
plt.xlabel('Epochs'); plt.ylabel('Accuracy'); plt.title('Accuracy over Epochs'); plt.legend()
plt.tight_layout(); plt.show()

# ==============================================================================
# 8. EVALUATION
# ==============================================================================
print("\n--- Evaluating Model on Test Set ---")
model.load_state_dict(torch.load(os.path.join(checkpoints_path, "best_model.pt")))
def evaluate_model_full(model, dataloader):
    model.eval(); y_true, y_pred, y_prob = [], [], []
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            probs = F.softmax(outputs, dim=1)
            _, predicted = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy()); y_pred.extend(predicted.cpu().numpy()); y_prob.extend(probs.cpu().numpy())
    return np.array(y_true), np.array(y_pred), np.array(y_prob)

y_true, y_pred, y_prob = evaluate_model_full(model, test_dataloader)
print(f"Overall Test Accuracy: {accuracy_score(y_true, y_pred):.3f}")
print("\nClassification Report:"); print(classification_report(y_true, y_pred, target_names=class_names))
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label'); plt.ylabel('True Label'); plt.title('Confusion Matrix'); plt.show()

# --- ROC Curve and AUC Score ---
y_true_binarized = label_binarize(y_true, classes=range(total_class))
fpr, tpr, roc_auc = {}, {}, {}
for i in range(total_class):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
plt.figure(figsize=(10, 8)); colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green'])
for i, color in zip(range(total_class), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'ROC curve of class {class_names[i]} (AUC = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--', lw=2); plt.xlim([0.0, 1.0]); plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate'); plt.ylabel('True Positive Rate'); plt.title('Multi-class ROC Curve for MobileNetV2'); plt.legend(loc="lower right"); plt.show()

# ==============================================================================
# 9. EXPLAINABLE AI (Grad-CAM)
# ==============================================================================
class GradCAM:
    def __init__(self, model, target_layer):
        self.model=model; self.target_layer=target_layer; self.gradients=None; self.activations=None; self.hook_handles=[]
        self._register_hooks()
    def _register_hooks(self):
        def f_hook(module, input, output): self.activations = output.detach()
        def b_hook(module, grad_input, grad_output): self.gradients = grad_output[0].detach()
        self.hook_handles.extend([self.target_layer.register_forward_hook(f_hook), self.target_layer.register_backward_hook(b_hook)])
    def remove_hooks(self):
        for handle in self.hook_handles: handle.remove()
    def generate_cam(self, input_tensor, target_class=None):
        self.model.eval(); input_tensor.requires_grad_(True); output = self.model(input_tensor)
        if target_class is None: target_class = output.argmax(dim=1).item()
        self.model.zero_grad(); class_score = output[:, target_class]; class_score.backward()
        weights = torch.mean(self.gradients, dim=(2, 3), keepdim=True)
        cam = torch.sum(weights * self.activations, dim=1).squeeze().cpu().numpy()
        cam = np.maximum(cam, 0); cam = cv2.resize(cam, (224, 224)); cam = (cam - np.min(cam)) / (np.max(cam) - np.min(cam) + 1e-8)
        return cam
def denormalize_image(tensor, mean, std):
    tensor = tensor.clone()
    for t, m, s in zip(tensor, mean, std): t.mul_(s).add_(m)
    return tensor
def show_gradcam(model, dataloader, device, target_layer, classes, num_samples=5):
    gradcam = GradCAM(model, target_layer); data_iter = iter(dataloader)
    plt.figure(figsize=(8, num_samples * 3))
    for i in range(num_samples):
        inputs, labels = next(data_iter); input_tensor = inputs[0].unsqueeze(0).to(device); label = labels[0].item()
        output = model(input_tensor); pred_class = output.argmax(dim=1).item()
        cam = gradcam.generate_cam(input_tensor, pred_class)
        mean_t = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1); std_t = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
        img_denorm = denormalize_image(inputs[0].cpu(), mean_t, std_t); img_np = np.clip(img_denorm.numpy().transpose(1, 2, 0), 0, 1)
        heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
        overlay = cv2.addWeighted(cv2.cvtColor(np.uint8(255 * img_np), cv2.COLOR_RGB2BGR), 0.6, heatmap, 0.4, 0)
        plt.subplot(num_samples, 2, 2 * i + 1); plt.imshow(img_np); plt.title(f"Original\nTrue: {classes[label]}"); plt.axis('off')
        plt.subplot(num_samples, 2, 2 * i + 2); plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB)); plt.title(f"Grad-CAM\nPredicted: {classes[pred_class]}"); plt.axis('off')
    plt.tight_layout(); plt.show(); gradcam.remove_hooks()

print("\n--- Grad-CAM Visualization ---")
target_layer = model.features[-1] 
show_gradcam(model, test_dataloader, device, target_layer, class_names, num_samples=5)
# Out:
# --- System Information ---
# GPU: Tesla P100-PCIE-16GB
#
# --- Dataset Split Ratios ---
# Train: 700 images (70.00%)
# Validation: 150 images (15.00%)
# Test: 150 images (15.00%)
# Processing train set:   0%|          | 0/700 [00:00<?, ?it/s]
# Processing validation set:   0%|          | 0/150 [00:00<?, ?it/s]
# Processing test set:   0%|          | 0/150 [00:00<?, ?it/s]
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# --- Label Encoding ---
# Bacterial Leaf Disease -> 0
# Dried Leaf -> 1
# Fungal Brown Spot Disease -> 2
# Healthy Leaf -> 3
#
# --- Initializing MobileNetV2 Model ---
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 149MB/s]
# --- Stage 1: Training the Classifier (Frozen Base) ---
# Epoch 1/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 1/20 -> Train Loss: 1.336, Train Acc: 0.351 | Val Loss: 1.166, Val Acc: 0.633
# ✅ Best model from Stage 1 saved with validation accuracy: 0.633
# Epoch 2/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 2/20 -> Train Loss: 1.159, Train Acc: 0.584 | Val Loss: 1.003, Val Acc: 0.767
# ✅ Best model from Stage 1 saved with validation accuracy: 0.767
# Epoch 3/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 3/20 -> Train Loss: 1.015, Train Acc: 0.691 | Val Loss: 0.882, Val Acc: 0.833
# ✅ Best model from Stage 1 saved with validation accuracy: 0.833
# Epoch 4/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 4/20 -> Train Loss: 0.911, Train Acc: 0.764 | Val Loss: 0.781, Val Acc: 0.847
# ✅ Best model from Stage 1 saved with validation accuracy: 0.847
# Epoch 5/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 5/20 -> Train Loss: 0.844, Train Acc: 0.773 | Val Loss: 0.705, Val Acc: 0.847
# Epoch 6/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 6/20 -> Train Loss: 0.757, Train Acc: 0.821 | Val Loss: 0.651, Val Acc: 0.853
# ✅ Best model from Stage 1 saved with validation accuracy: 0.853
# Epoch 7/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 7/20 -> Train Loss: 0.725, Train Acc: 0.816 | Val Loss: 0.602, Val Acc: 0.867
# ✅ Best model from Stage 1 saved with validation accuracy: 0.867
# Epoch 8/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 8/20 -> Train Loss: 0.654, Train Acc: 0.880 | Val Loss: 0.561, Val Acc: 0.873
# ✅ Best model from Stage 1 saved with validation accuracy: 0.873
# Epoch 9/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 9/20 -> Train Loss: 0.629, Train Acc: 0.844 | Val Loss: 0.523, Val Acc: 0.873
# Epoch 10/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 10/20 -> Train Loss: 0.582, Train Acc: 0.864 | Val Loss: 0.499, Val Acc: 0.887
# ✅ Best model from Stage 1 saved with validation accuracy: 0.887
# Epoch 11/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 11/20 -> Train Loss: 0.574, Train Acc: 0.844 | Val Loss: 0.480, Val Acc: 0.867
# Epoch 12/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 12/20 -> Train Loss: 0.523, Train Acc: 0.866 | Val Loss: 0.461, Val Acc: 0.873
# Epoch 13/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 13/20 -> Train Loss: 0.510, Train Acc: 0.867 | Val Loss: 0.435, Val Acc: 0.893
# ✅ Best model from Stage 1 saved with validation accuracy: 0.893
# Epoch 14/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 14/20 -> Train Loss: 0.479, Train Acc: 0.874 | Val Loss: 0.420, Val Acc: 0.880
# Epoch 15/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 15/20 -> Train Loss: 0.481, Train Acc: 0.870 | Val Loss: 0.401, Val Acc: 0.900
# ✅ Best model from Stage 1 saved with validation accuracy: 0.900
# Epoch 16/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 16/20 -> Train Loss: 0.453, Train Acc: 0.889 | Val Loss: 0.387, Val Acc: 0.900
# Epoch 17/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 17/20 -> Train Loss: 0.440, Train Acc: 0.896 | Val Loss: 0.375, Val Acc: 0.893
# Epoch 18/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 18/20 -> Train Loss: 0.443, Train Acc: 0.887 | Val Loss: 0.364, Val Acc: 0.907
# ✅ Best model from Stage 1 saved with validation accuracy: 0.907
# Epoch 19/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 19/20 -> Train Loss: 0.424, Train Acc: 0.891 | Val Loss: 0.344, Val Acc: 0.913
# ✅ Best model from Stage 1 saved with validation accuracy: 0.913
# Epoch 20/20 [T]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 20/20 -> Train Loss: 0.417, Train Acc: 0.890 | Val Loss: 0.345, Val Acc: 0.900
#
# --- Stage 2: Fine-Tuning (Unfrozen Base) ---
# Epoch 1/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 1/15 -> Train Loss: 0.349, Train Acc: 0.916 | Val Loss: 0.269, Val Acc: 0.920
# ✅ Best model from Stage 2 saved with validation accuracy: 0.920
# Epoch 2/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 2/15 -> Train Loss: 0.298, Train Acc: 0.927 | Val Loss: 0.214, Val Acc: 0.927
# ✅ Best model from Stage 2 saved with validation accuracy: 0.927
# Epoch 3/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 3/15 -> Train Loss: 0.256, Train Acc: 0.931 | Val Loss: 0.186, Val Acc: 0.940
# ✅ Best model from Stage 2 saved with validation accuracy: 0.940
# Epoch 4/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 4/15 -> Train Loss: 0.207, Train Acc: 0.949 | Val Loss: 0.164, Val Acc: 0.947
# ✅ Best model from Stage 2 saved with validation accuracy: 0.947
# Epoch 5/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 5/15 -> Train Loss: 0.178, Train Acc: 0.957 | Val Loss: 0.146, Val Acc: 0.947
#    (No improvement for 1 epochs)
# Epoch 6/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 6/15 -> Train Loss: 0.176, Train Acc: 0.954 | Val Loss: 0.135, Val Acc: 0.960
# ✅ Best model from Stage 2 saved with validation accuracy: 0.960
# Epoch 7/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 7/15 -> Train Loss: 0.179, Train Acc: 0.950 | Val Loss: 0.121, Val Acc: 0.947
#    (No improvement for 1 epochs)
# Epoch 8/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 8/15 -> Train Loss: 0.141, Train Acc: 0.969 | Val Loss: 0.111, Val Acc: 0.953
#    (No improvement for 2 epochs)
# Epoch 9/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 9/15 -> Train Loss: 0.130, Train Acc: 0.963 | Val Loss: 0.105, Val Acc: 0.960
#    (No improvement for 3 epochs)
# Epoch 10/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 10/15 -> Train Loss: 0.119, Train Acc: 0.967 | Val Loss: 0.102, Val Acc: 0.967
# ✅ Best model from Stage 2 saved with validation accuracy: 0.967
# Epoch 11/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 11/15 -> Train Loss: 0.109, Train Acc: 0.970 | Val Loss: 0.090, Val Acc: 0.960
#    (No improvement for 1 epochs)
# Epoch 12/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 12/15 -> Train Loss: 0.115, Train Acc: 0.964 | Val Loss: 0.087, Val Acc: 0.967
#    (No improvement for 2 epochs)
# Epoch 13/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 13/15 -> Train Loss: 0.103, Train Acc: 0.974 | Val Loss: 0.085, Val Acc: 0.967
#    (No improvement for 3 epochs)
# Epoch 14/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 14/15 -> Train Loss: 0.086, Train Acc: 0.981 | Val Loss: 0.081, Val Acc: 0.967
#    (No improvement for 4 epochs)
# Epoch 15/15 [FT]:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch 15/15 -> Train Loss: 0.088, Train Acc: 0.977 | Val Loss: 0.081, Val Acc: 0.973
# ✅ Best model from Stage 2 saved with validation accuracy: 0.973
#
# --- Training & Fine-Tuning Finished ---
# Total Time: 1.44 minutes
# --- Evaluating Model on Test Set ---
# Overall Test Accuracy: 0.940
#
# Classification Report:
#                            precision    recall  f1-score   support
#
#    Bacterial Leaf Disease       0.97      0.89      0.93        38
#                Dried Leaf       1.00      1.00      1.00        37
# Fungal Brown Spot Disease       0.92      0.92      0.92        38
#              Healthy Leaf       0.88      0.95      0.91        37
#
#                  accuracy                           0.94       150
#                 macro avg       0.94      0.94      0.94       150
#              weighted avg       0.94      0.94      0.94       150
# --- Grad-CAM Visualization ---
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
